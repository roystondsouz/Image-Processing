# %%
from skimage import io
import matplotlib.pyplot as plt
url='https://s3-ap-south-1.amazonaws.com/soulveda-media-prod/wp-content/uploads/2021/03/19125430/Its-time-we-nurtured-Mother-Earth.jpg'
image=io.imread(url)
plt.imshow(image)
plt.show()
