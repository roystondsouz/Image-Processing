# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
img=cv2.imread('flower4.jpg',0)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.image as mping
import matplotlib.pyplot as plt
image=cv2.imread('PLANTS 3.jpg')
plt.imshow(image)
plt.show()

# %%
from PIL import Image
Original_Image=Image.open('PLANTS 1.jpg')
rotate_image1=Original_Image.rotate(180)
rotate_image1.show()

# %%
from PIL import ImageColor
img1=ImageColor.getrgb("yellow")
print(img1)
img2=ImageColor.getrgb("brown")
print(img2)
# Out:
# (255, 255, 0)
# (165, 42, 42)

# %%
from PIL import Image
img=Image.new('RGB',(200,40),(255,196,0))
img.show()

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('PLANTS 2.jpg')
plt.imshow(img)
plt.show()
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
img=cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
plt.imshow(img)
plt.show()
img=cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
plt.imshow(img)
plt.show()

# %%
from PIL import Image
image=Image.open("PLANTS 3.jpg")
print("Filename:",image.filename)
print("Format:",image.format)
print("Mode:",image.mode)
print("Size:",image.size)
print("Width:",image.width)
print("Height:",image.height)
image.close()
# Out:
# Filename: PLANTS 3.jpg
# Format: JPEG
# Mode: RGB
# Size: (181, 279)
# Width: 181
# Height: 279

# %%
import cv2
img=cv2.imread("PLANTS 1.jpg")
print('origial image length width',img.shape)
cv2.imshow('original image',img)
cv2.waitKey(0)
#to show the resized image
imgresize=cv2.resize(img,(150,160))
cv2.imshow('Resized image',imgresize)
print('Resized image length, width',imgresize.shape)
cv2.waitKey(0)
# Out:
# origial image length width (185, 273, 3)
# Resized image length, width (160, 150, 3)
# -1

# %%
import cv2
#read the image file
img=cv2.imread('leaf3.jpg')
cv2.imshow("RGB",img)
cv2.waitKey(0)

#Grayscale

img=cv2.imread('leaf3.jpg',0)
cv2.imshow("Gray",img)
cv2.waitKey(0)

#Binary image

ret,bw_img=cv2.threshold(img,127,255,cv2.THRESH_BINARY)
cv2.imshow("Binary",bw_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
